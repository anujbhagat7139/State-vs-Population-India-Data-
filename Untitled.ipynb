# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("Copy of Copy of 3.4 State and UTs of India.csv")

# %%
df.head()
# Out:
#               State  Population  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0     Andhra Pradesh   49506799         NaN         NaN         NaN
# 1  Arunachal Pradesh    1383727         NaN         NaN         NaN
# 2              Assam   31205576         NaN         NaN         NaN
# 3              Bihar  104099452         NaN         NaN         NaN
# 4       Chhattisgarh   25545198         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        36 non-null     object
#  1   Population   36 non-null     object
#  2   Unnamed: 2   0 non-null      float64
#  3   Unnamed: 3   0 non-null      float64
#  4   Unnamed: 4   0 non-null      float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
df.columns
# Out:
# Index(['State ', 'Population', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df.drop(columns=df.columns[2:],inplace=True)

# %%
df.head()
# Out:
#               State  Population
# 0     Andhra Pradesh   49506799
# 1  Arunachal Pradesh    1383727
# 2              Assam   31205576
# 3              Bihar  104099452
# 4       Chhattisgarh   25545198

# %%
df.columns
# Out:
# Index(['State ', 'Population'], dtype='object')

# %%
df['Population'][3]
# Out:
# '104099452'

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head()
# Out:
#               State  Population
# 0     Andhra Pradesh   49506799
# 1  Arunachal Pradesh    1383727
# 2              Assam   31205576
# 3              Bihar  104099452
# 4       Chhattisgarh   25545198

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State       36 non-null     object
#  1   Population  36 non-null     object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
df.head()
# Out:
#               State  Population
# 0     Andhra Pradesh   49506799
# 1  Arunachal Pradesh    1383727
# 2              Assam   31205576
# 3              Bihar  104099452
# 4       Chhattisgarh   25545198

# %%
df
# Out:
#                                       State       Population
# 0                             Andhra Pradesh        49506799
# 1                          Arunachal Pradesh         1383727
# 2                                      Assam        31205576
# 3                                      Bihar       104099452
# 4                               Chhattisgarh        25545198
# 5                                        Goa         1458545
# 6                                    Gujarat        60439692
# 7                                    Haryana        25351462
# 8                           Himachal Pradesh         6864602
# 9                                  Jharkhand        32988134
# 10                                 Karnataka        61095297
# 11                                    Kerala        33406061
# 12                            Madhya Pradesh        72626809
# 13                               Maharashtra       112374333
# ...

# %%
df.loc[df['State '] == 'Telangana', 'Population'] = 37725000

# %%
df
# Out:
#                                       State  Population
# 0                             Andhra Pradesh   49506799
# 1                          Arunachal Pradesh    1383727
# 2                                      Assam   31205576
# 3                                      Bihar  104099452
# 4                               Chhattisgarh   25545198
# 5                                        Goa    1458545
# 6                                    Gujarat   60439692
# 7                                    Haryana   25351462
# 8                           Himachal Pradesh    6864602
# 9                                  Jharkhand   32988134
# 10                                 Karnataka   61095297
# 11                                    Kerala   33406061
# 12                            Madhya Pradesh   72626809
# 13                               Maharashtra  112374333
# 14                                   Manipur    2855794
# 15                                 Meghalaya    2966889
# ...

# %%
df['Population'] = df['Population'].astype(int)

# %%
df.columns
# Out:
# Index(['State ', 'Population'], dtype='object')

# %%
df
# Out:
#                                       State   Population
# 0                             Andhra Pradesh    49506799
# 1                          Arunachal Pradesh     1383727
# 2                                      Assam    31205576
# 3                                      Bihar   104099452
# 4                               Chhattisgarh    25545198
# 5                                        Goa     1458545
# 6                                    Gujarat    60439692
# 7                                    Haryana    25351462
# 8                           Himachal Pradesh     6864602
# 9                                  Jharkhand    32988134
# 10                                 Karnataka    61095297
# 11                                    Kerala    33406061
# 12                            Madhya Pradesh    72626809
# 13                               Maharashtra   112374333
# 14                                   Manipur     2855794
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State       36 non-null     object
#  1   Population  36 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 720.0+ bytes

# %%
df.head()
# Out:
#               State   Population
# 0     Andhra Pradesh    49506799
# 1  Arunachal Pradesh     1383727
# 2              Assam    31205576
# 3              Bihar   104099452
# 4       Chhattisgarh    25545198

# %%
df.sort_values(by='Population',ascending=False).head()
# Out:
#             State   Population
# 25   Uttar Pradesh   199812341
# 13     Maharashtra   112374333
# 3            Bihar   104099452
# 27     West Bengal    91276115
# 12  Madhya Pradesh    72626809

# %%
df.columns
# Out:
# Index(['State ', 'Population'], dtype='object')

# %%
sns.boxplot(data=df,y="State ",x="Population")
# Out:
# <AxesSubplot:xlabel='Population', ylabel='State '>

# %%
sns.barplot(y="Population",x="State ",data=df)
# Out:
# <AxesSubplot:xlabel='State ', ylabel='Population'>
